# %%
import pandas as pd

data = {
    'character_names': ['Robert Nash', 'Evan Buckley', 'Eddie Diaz', 'Henrietta Wilson', 'Howard Han', 'Christopher Diaz', 'Maddie Buckley Han', 'Athena Grant'],
    'nicknames': ['Bobby', 'Buck', 'Eddie', 'Hen', 'Chimney', 'Chris', 'Maddie', 'Thena'],
    'job':['Captain (former)', 'Firefighter', 'Firefighter', 'Paramedic', 'Captain', 'Student', 'Dispatcher', 'Police Sergent'],
    'age': [56, 39, 38, 42, 46, 14, 36, 51],
    'relationship': [True, True, True, True, True, False, True, True]
}

characters = pd.DataFrame(data)
characters
# Out:
#       character_names nicknames               job  age  relationship
# 0         Robert Nash     Bobby  Captain (former)   56          True
# 1        Evan Buckley      Buck       Firefighter   39          True
# 2          Eddie Diaz     Eddie       Firefighter   38          True
# 3    Henrietta Wilson       Hen         Paramedic   42          True
# 4          Howard Han   Chimney           Captain   46          True
# 5    Christopher Diaz     Chris           Student   14         False
# 6  Maddie Buckley Han    Maddie        Dispatcher   36          True
# 7        Athena Grant     Thena    Police Sergent   51          True

# %%
# add a column for who they are in relationship with:
characters['partner'] = ['Athena Grant', 'Eddie Diaz', 'Evan Buckley', 'Karen', 'Maddie Buckley Han', 'None', 'Howard Han', 'Robert Nash']
characters
# Out:
#       character_names nicknames               job  age  relationship  \
# 0         Robert Nash     Bobby  Captain (former)   56          True
# 1        Evan Buckley      Buck       Firefighter   39          True
# 2          Eddie Diaz     Eddie       Firefighter   38          True
# 3    Henrietta Wilson       Hen         Paramedic   42          True
# 4          Howard Han   Chimney           Captain   46          True
# 5    Christopher Diaz     Chris           Student   14         False
# 6  Maddie Buckley Han    Maddie        Dispatcher   36          True
# 7        Athena Grant     Thena    Police Sergent   51          True
#
#               partner
# 0        Athena Grant
# 1          Eddie Diaz
# 2        Evan Buckley
# 3               Karen
# 4  Maddie Buckley Han
# 5                None
# 6          Howard Han
# 7         Robert Nash

# %%
# sort data frame by stat- i'll do age :D
characters_sorted = characters.sort_values(by='age', ascending=False)
characters_sorted
# Out:
#       character_names nicknames               job  age  relationship  \
# 0         Robert Nash     Bobby  Captain (former)   56          True
# 7        Athena Grant     Thena    Police Sergent   51          True
# 4          Howard Han   Chimney           Captain   46          True
# 3    Henrietta Wilson       Hen         Paramedic   42          True
# 1        Evan Buckley      Buck       Firefighter   39          True
# 2          Eddie Diaz     Eddie       Firefighter   38          True
# 6  Maddie Buckley Han    Maddie        Dispatcher   36          True
# 5    Christopher Diaz     Chris           Student   14         False
#
#               partner
# 0        Athena Grant
# 7         Robert Nash
# 4  Maddie Buckley Han
# 3               Karen
# 1          Eddie Diaz
# 2        Evan Buckley
# 6          Howard Han
# 5                None

# %%
# get paramedics only:
paramedics = characters[characters['job']=='Paramedic']
paramedics
# Out:
#     character_names nicknames        job  age  relationship partner
# 3  Henrietta Wilson       Hen  Paramedic   42          True   Karen

# %%
# over forty:
over_forty = characters[characters['age']>=40]
over_forty
# Out:
#     character_names nicknames               job  age  relationship  \
# 0       Robert Nash     Bobby  Captain (former)   56          True
# 3  Henrietta Wilson       Hen         Paramedic   42          True
# 4        Howard Han   Chimney           Captain   46          True
# 7      Athena Grant     Thena    Police Sergent   51          True
#
#               partner
# 0        Athena Grant
# 3               Karen
# 4  Maddie Buckley Han
# 7         Robert Nash
